# %%
"""Splitting text data into tokens."""
# Modificado de https://github.com/TianHuaBooks/Count/blob/master/count_words.py
import re
import numpy as np
import pandas as pd

counts = dict()  # diccionario de pares { <word>: <count> }
cantwordbo = [] #Cantidad de palabras por libro
numdocs = dict() #Numero de documentos que contengan palabra
idf = dict() #Numero de documentos que contengan palabra
vocabulario = [] #WORDS
num_libros=0

# %%
def sent_tokenize(text):
    """Split text into sentences."""

    # Split text by sentence delimiters (remove delimiters)
    sentenses = re.split(r"[\n|\r]", text)

    print("# of lines:{}".format(len(sentenses)))

    # Remove leading and trailing spaces from each sentence
    results = []
    for sen in sentenses:
        s = sen.strip()
        if len(s):
            results.append(s)
    num_libros=len(results)
    return results


def word_tokenize(sent):
    """Split a sentence into words."""
    """Cuenta cuantas veces una palabra occure en el texto"""
    

    # Conversion a minuscula
    text = sent.lower()
    palabras_libro=dict()
    
    # Dividir el texto en tokens (palabras), quitando la puntuacion.
    # Usar expresiones regulares para dividr segun caracteres no-alfanumericos '\w'
    matchObjs = re.findall(r'[\w]+', text)
    
    n_palabras=len(matchObjs)
    
    print(matchObjs)
    # Conteo usando el diccionario.
    for obj in matchObjs:
        if obj in counts:
            counts[obj] += 1  # Adiciona 1 a una entrada existente
        else:
            counts[obj] = 1  # Crea un nuevo indice/palabra en el diccionario.
            vocabulario.append(obj)
            
            
        if obj in palabras_libro: # Frecuencia en el texto
            palabras_libro[obj] += 1  # Adiciona 1 a una entrada existente
        else:
            palabras_libro[obj] = 1  # Crea un nuevo indice/palabra en el diccionario.
            if obj in numdocs: # df
                numdocs[obj] += 1  # Adiciona 1 a una entrada existente
            else:
                numdocs[obj] = 1  # Crea un nuevo indice/palabra en el diccionario.
    print("DF")    
    print(numdocs) 
    print("DF")    
    for k in palabras_libro:
        palabras_libro[k]=palabras_libro.get(k)/n_palabras
    cantwordbo.append(palabras_libro)
    print("Frecuencia TF")
    print(palabras_libro)
    print("")
    
    
    return counts

def sumarnums(llave, valor):

    tablal = []
    tablav = []
    print(valor)
    print("\n Imprimir tablas \n")
    for ll in llave:
        tablal.append(ll)
    print("\n Llaves")
    print(tablal)

    for ll in valor:
        tablav.append(ll)
    print("\n Valor")
    print(tablav)
    tablal.extend(tablav)
    print ("Con metodo .extend()")
    print (tablal)
    
    #for tablita in tablal:
     #   print("\n", tablita)

# %%
def Calcular_idf():
    for palabra in vocabulario:
        idf[palabra]= num_libros/numdocs.get(palabra)
        
    print("idf")
    print(idf)
    print("idf")

# %%
def test_run():
    """Called on Test Run."""
    with open("mycorpus.txt", "r") as f:
        text = f.read()
        # print("--- Sample text ---", text, sep="\n")

    sentences = sent_tokenize(text)
    print("\n--- Sentences ---")
    #print(sentences)
    cont = 1
    print("\n--- Words ---")
    for sent in sentences:
        print(".............................................................................................")
        print("\n")
        print("Libro # ", cont)
        print(sent)
        print("\n")
        #Diccionario con las palabras y el total de veces que aparecen
        word = word_tokenize(sent)
        #Se convierten los valores del diccionario a una lista.
        keys = word.keys()
        values = word.values()
        print("\n")
        print("TUPLAS")
        #print(values)
        #Enviar lista para realizar calculos e imprimir primera tabla
        print("\n")
        #tablaimpresa = sumarnums(keys,values)
    
        sorted_counts = sorted(word.items(), key=lambda pair: pair[1], reverse=True)
        print("\n")
        print(word)
        print("\n")
        print("10 most common words:\nWord\tCount")

       # for word, count in sorted_counts[:10]:
        #    print("{}\t{}".format(word, count))

        print("\n10 least common words:\nWord\tCount")
        #for word, count in sorted_counts[-10:]:
         #   print("{}\t{}".format(word, count))

        print("\n")
        print(sorted_counts)
        print()  # blank line for readability
        cont += 1
        
    Calcular_idf()

if __name__ == "__main__":
    test_run()
# Out:
# # of lines:12
#
# --- Sentences ---
#
# --- Words ---
# .............................................................................................
#
#
# Libro #  1
# Amazon distributes downloads and streaming of video, music, audiobook through its Amazon Prime Video, Amazon Music, and Audible subsidiaries. Amazon also has a publishing arm, Amazon Publishing, a film and television studio, Amazon Studios, and a cloud computing subsidiary, Amazon Web Services.
#
#
# ['amazon', 'distributes', 'downloads', 'and', 'streaming', 'of', 'video', 'music', 'audiobook', 'through', 'its', 'amazon', 'prime', 'video', 'amazon', 'music', 'and', 'audible', 'subsidiaries', 'amazon', 'also', 'has', 'a', 'publishing', 'arm', 'amazon', 'publishing', 'a', 'film', 'and', 'television', 'studio', 'amazon', 'studios', 'and', 'a', 'cloud', 'computing', 'subsidiary', 'amazon', 'web', 'services']
# DF
# {'amazon': 1, 'distributes': 1, 'downloads': 1, 'and': 1, 'streaming': 1, 'of': 1, 'video': 1, 'music': 1, 'audiobook': 1, 'through': 1, 'its': 1, 'prime': 1, 'audible': 1, 'subsidiaries': 1, 'also': 1, 'has': 1, 'a': 1, 'publishing': 1, 'arm': 1, 'film': 1, 'television': 1, 'studio': 1, 'studios': 1, 'cloud': 1, 'computing': 1, 'subsidiary': 1, 'web': 1, 'services': 1}
# DF
# Frecuencia TF
# {'amazon': 0.16666666666666666, 'distributes': 0.023809523809523808, 'downloads': 0.023809523809523808, 'and': 0.09523809523809523, 'streaming': 0.023809523809523808, 'of': 0.023809523809523808, 'video': 0.047619047619047616, 'music': 0.047619047619047616, 'audiobook': 0.023809523809523808, 'through': 0.023809523809523808, 'its': 0.023809523809523808, 'prime': 0.023809523809523808, 'audible': 0.023809523809523808, 'subsidiaries': 0.023809523809523808, 'also': 0.023809523809523808, 'has': 0.023809523809523808, 'a': 0.07142857142857142, 'publishing': 0.047619047619047616, 'arm': 0.023809523809523808, 'film': 0.023809523809523808, 'television': 0.023809523809523808, 'studio': 0.023809523809523808, 'studios': 0.023809523809523808, 'cloud': 0.023809523809523808, 'computing': 0.023809523809523808, 'subsidiary': 0.023809523809523808, 'web': 0.023809523809523808, 'services': 0.023809523809523808}
#
#
#
# TUPLAS
#
#
#
#
# {'amazon': 7, 'distributes': 1, 'downloads': 1, 'and': 4, 'streaming': 1, 'of': 1, 'video': 2, 'music': 2, 'audiobook': 1, 'through': 1, 'its': 1, 'prime': 1, 'audible': 1, 'subsidiaries': 1, 'also': 1, 'has': 1, 'a': 3, 'publishing': 2, 'arm': 1, 'film': 1, 'television': 1, 'studio': 1, 'studios': 1, 'cloud': 1, 'computing': 1, 'subsidiary': 1, 'web':
 'prime': 1, 'audible': 1, 'subsidiaries': 1, 'also': 1, 'has': 1, 'a': 3, 'publishing': 2, 'arm': 1, 'film': 1, 'television': 1, 'studio': 1, 'studios': 1, 'cloud': 1, 'computing': 1, 'subsidiary': 1, 'web': 2, 'services': 2, 'microsoft': 3, 'corporation': 1, 'is': 1, 'an': 1, 'american': 1, 'multinational': 1, 'technology': 1, 'company': 1, 'with': 1, 'headquarters': 1, 'in': 1, 'redmond': 1, 'washington': 1, 'it': 1, 'develops': 1, 'manufactures': 1, 'licenses': 1, 'supports': 1, 'sells': 1, 'computer': 1, 'software': 2, 'consumer': 1, 'electronics': 1, 'personal': 1, 'computers': 1, 'related': 1, 'best': 1, 'known': 1, 'products': 1, 'are': 1, 'the': 3, 'windows': 1, 'line': 1, 'operating': 1, 'systems': 1, 'office': 1, 'suite': 1, 'internet': 1, 'explorer': 1, 'edge': 1, 'browsers': 1}
#
#
# 10 most common words:
# Word	Count
#
# 10 least common words:
# Word	Count
#
#
# [('and', 8), ('amazon', 7), ('a', 3), ('microsoft', 3), ('the', 3), ('of', 2), ('video', 2), ('music', 2), ('its', 2), ('publishing', 2), ('web', 2), ('services', 2), ('software', 2), ('distributes', 1), ('downloads', 1), ('streaming', 1), ('audiobook', 1), ('through', 1), ('prime', 1), ('audible', 1), ('subsidiaries', 1), ('also', 1), ('has', 1), ('arm', 1), ('film', 1), ('television', 1), ('studio', 1), ('studios', 1), ('cloud', 1), ('computing', 1), ('subsidiary', 1), ('corporation', 1), ('is', 1), ('an', 1), ('american', 1), ('multinational', 1), ('technology', 1), ('company', 1), ('with', 1), ('headquarters', 1), ('in', 1), ('redmond', 1), ('washington', 1), ('it', 1), ('develops', 1), ('manufactures', 1), ('licenses', 1), ('supports', 1), ('sells', 1), ('computer', 1), ('consumer', 1), ('electronics', 1), ('personal', 1), ('computers', 1), ('related', 1), ('best', 1), ('known', 1), ('products', 1), ('are', 1), ('windows', 1), ('line', 1), ('operating', 1), ('systems', 1), ('office', 1), ('suite', 1), ('internet', 1), ('explorer', 1), ('edge', 1), ('browsers', 1)]
#
# .............................................................................................
#
#
# Libro #  3
# Google was founded in 1998 by Larry Page and Sergey Brin while they were Ph.D. students at Stanford University in California. Together they own about 14 percent of its shares and control 56 percent of the stockholder voting power through supervoting stock. They incorporated Google as a privately held company on September 4, 1998.
#
#
# ['google', 'was', 'founded', 'in', '1998', 'by', 'larry', 'page', 'and', 'sergey', 'brin', 'while', 'they', 'were', 'ph', 'd', 'students', 'at', 'stanford', 'university', 'in', 'california', 'together', 'they', 'own', 'about', '14', 'percent', 'of', 'its', 'shares', 'and', 'control', '56', 'percent', 'of', 'the', 'stockholder', 'voting', 'power', 'through', 'supervoting', 'stock', 'they', 'incorporated', 'google', 'as', 'a', 'privately', 'held', 'company', 'on', 'september', '4', '1998']
# DF
# {'amazon': 1, 'distributes': 1, 'downloads': 1, 'and': 3, 'streaming': 1, 'of': 3, 'video': 1, 'music': 1, 'audiobook': 1, 'through': 2, 'its': 3, 'prime': 1, 'audible': 1, 'subsidiaries': 1, 'also': 1, 'has': 1, 'a': 2, 'publishing': 1, 'arm': 1, 'film': 1, 'television': 1, 'studio': 1, 'studios': 1, 'cloud': 1, 'computing': 1, 'subsidiary': 1, 'web': 2, 'services': 2, 'microsoft': 1, 'corporation': 1, 'is': 1, 'an': 1, 'american': 1, 'multinational': 1, 'technology': 1, 'company': 2, 'with': 1, 'headquarters': 1, 'in': 2, 'redmond': 1, 'washington': 1, 'it': 1, 'develops': 1, 'manufactures': 1, 'licenses': 1, 'supports': 1, 'sells': 1, 'computer': 1, 'software': 1, 'consumer': 1, 'electronics': 1, 'personal': 1, 'computers': 1, 'related': 1, 'best': 1, 'known': 1, 'products': 1, 'are': 1, 'the': 2, 'windows': 1, 'line': 1, 'operating': 1, 'systems': 1, 'office': 1, 'suite': 1, 'internet': 1, 'explorer': 1, 'edge': 1, 'browsers': 1, 'google': 1, 'was': 1, 'founded': 1, '1998': 1, 'by': 1, 'larry': 1, 'page': 1, 'sergey': 1, 'brin': 1, 'while': 1, 'they': 1, 'were': 1, 'ph': 1, 'd': 1, 'students': 1, 'at': 1, 'stanford': 1, 'university': 1, 'california': 1, 'together': 1, 'own': 1, 'about': 1, '14': 1, 'percent': 1, 'shares': 1, 'control': 1, '56': 1, 'stockholder': 1, 'voting': 1, 'power': 1, 'supervoting': 1, 'stock': 1, 'incorporated': 1, 'as': 1, 'privately': 1, 'held': 1, 'on': 1, 'september': 1, '4': 1}
# DF
# Frecuencia TF
# {'google': 0.03636363636363636, 'was': 0.01818181818181818, 'founded': 0.01818181818181818, 'in': 0.03636363636363636, '1998': 0.03636363636363636, 'by': 0.01818181818181818, 'larry': 0.01818181818181818, 'page': 0.01818181818181818, 'and': 0.03636363636363636, 'sergey': 0.01818181818181818, 'brin': 0.01818181818181818, 'while': 0.01818181818181818, 'they': 0.05454545454545454, 'were': 0.01818181818181818, 'ph': 0.01818181818181818, 'd': 0.01818181818181818, 'students': 0.01818181818181818, 'at': 0.01818181818181818, 'stanford': 0.01818181818181818, 'university': 0.01818181818181818, 'california': 0.01818181818181818, 'together': 0.01818181818181818, 'own': 0.01818181818181818, 'about': 0.01818181818181818, '14': 0.01818181818181818, 'percent': 0.03636363636363636, 'of': 0.03636363636363636, 'its': 0.01818181818181818, 'shares': 0.01818181818181818, 'control': 0.01818181818181818, '56': 0.01818181818181818, 'the': 0.01818181818181818, 'stockholder': 0.01818181818181818, 'voting': 0.01818181818181818, 'power': 0.01818181818181818, 'through': 0.01818181818181818, 'supervoting': 0.01818181818181818, 'stock': 0.01818181818181818, 'incorporated': 0.01818181818181818, 'as': 0.01818181818181818, 'a': 0.01818181818181818, 'privately': 0.01818181818181818, 'held': 0.01818181818181818, 'company': 0.01818181818181818, 'on': 0.01818181818181818, 'september': 0.01818181818181818, '4': 0.01818181818181818}
#
#
#
# TUPLAS
#
#
#
#
# {'amazon': 7, 'distributes': 1, 'downloads': 1, 'and': 10, 'streaming': 1, 'of': 4, 'video': 2, 'music': 2, 'audiobook': 1, 'through': 2, 'its': 3, 'prime': 1, 'audible': 1, 'subsidiaries': 1, 'also': 1, 'has': 1, 'a': 4, 'publishing': 2, 'arm': 1, 'film': 1, 'television': 1, 'studio': 1, 'studios': 1, 'cloud': 1, 'computing': 1, 'subsidiary': 1, 'web': 2, 'services': 2, 'microsoft': 3, 'corporation': 1, 'is': 1, 'an': 1, 'american': 1, 'multinational': 1, 'technology': 1, 'company': 2, 'with': 1, 'headquarters': 1, 'in': 3, 'redmond': 1, 'washington': 1, 'it': 1, 'develops': 1, 'manufactures': 1, 'licenses': 1, 'supports': 1, 'sells': 1, 'computer': 1, 'software': 2, 'consumer': 1, 'electronics': 1, 'personal': 1, 'computers': 1, 'related': 1, 'best': 1, 'known': 1, 'products': 1, 'are': 1, 'the': 4, 'windows': 1, 'line': 1, 'operating': 1, 'systems': 1, 'office': 1, 'suite': 1, 'internet': 1, 'explorer': 1, 'edge': 1, 'browsers': 1, 'google': 2, 'was': 1, 'founded': 1, '1998': 2, 'by': 1, 'larry': 1, 'page': 1, 'sergey': 1, 'brin': 1, 'while': 1, 'they': 3, 'were': 1, 'ph': 1, 'd': 1, 'students': 1, 'at': 1, 'stanford': 1, 'university': 1, 'california': 1, 'together': 1, 'own': 1, 'about': 1, '14': 1, 'percent': 2, 'shares': 1, 'control': 1, '56': 1, 'stockholder': 1, 'voting': 1, 'power': 1, 'supervoting': 1, 'stock': 1, 'incorporated': 1, 'as': 1, 'privately': 1, 'held': 1, 'on': 1, 'september': 1, '4': 1}
#
#
# 10 most common words:
# Word	Count
#
# 10 least common words:
# Word	Count
#
#
# [('and', 10), ('amazon', 7), ('of', 4), ('a', 4), ('the', 4), ('its', 3), ('microsoft', 3), ('in', 3), ('they', 3), ('video', 2), ('music', 2), ('through', 2), ('publishing', 2), ('web', 2), ('services', 2), ('company', 2), ('software', 2), ('google', 2), ('1998', 2), ('percent', 2), ('distributes', 1), ('downloads', 1), ('streaming', 1), ('audiobook', 1), ('prime', 1), ('audible', 1), ('subsidiaries', 1), ('also', 1), ('has', 1), ('arm', 1), ('film', 1), ('television', 1), ('studio', 1), ('studios', 1), ('cloud', 1), ('computing', 1), ('subsidiary', 1), ('corporation', 1), ('is', 1), ('an', 1), ('american', 1), ('multinational', 1), ('technology', 1), ('with', 1), ('headquarters', 1), ('redmond', 1), ('washington', 1), ('it', 1), ('develops', 1), ('manufactures', 1), ('licenses', 1), ('supports', 1), ('sells', 1), ('computer', 1), ('consumer', 1), ('electronics', 1), ('personal', 1), ('computers', 1), ('related', 1), ('best', 1), ('known', 1), ('products', 1), ('are', 1), ('windows', 1), ('line', 1), ('operating', 1), ('systems', 1), ('office', 1), ('suite', 1), ('internet', 1), ('explorer', 1), ('edge', 1), ('browsers', 1), ('was', 1), ('founded', 1), ('by', 1), ('larry', 1), ('page', 1), ('sergey', 1), ('brin', 1), ('while', 1), ('were', 1), ('ph', 1), ('d', 1), ('students', 1), ('at', 1), ('stanford', 1), ('university', 1), ('california', 1), ('together', 1), ('own', 1), ('about', 1), ('14', 1), ('shares', 1), ('control', 1), ('56', 1), ('stockholder', 1), ('voting', 1), ('power', 1), ('supervoting', 1), ('stock', 1), ('incorporated', 1), ('as', 1), ('privately', 1), ('held', 1), ('on', 1), ('september', 1), ('4', 1)]
#
# .............................................................................................
#
#
# Libro #  4
# Machine learning (ML) is the scientific study of algorithms and statistical models that computer systems use in order to perform a specific task effectively without using explicit instructions, relying on patterns and inference instead. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to perform the task.
#
#
# ['machine', 'learning', 'ml', 'is', 'the', 'scientific', 'study', 'of', 'algorithms', 'and', 'statistical', 'models', 'that', 'computer', 'systems', 'use', 'in', 'order', 'to', 'perform', 'a', 'specific', 'task', 'effectively', 'without', 'using', 'explicit', 'instructions', 'relying', 'on', 'patterns', 'and', 'inference', 'instead', 'it', 'is', 'seen', 'as', 'a', 'subset', 'of', 'artificial', 'intelligence', 'machine', 'learning', 'algorithms', 'build', 'a', 'mathematical', 'model', 'based', 'on', 'sample', 'data', 'known', 'as', 'training', 'data', 'in', 'order', 'to', 'make', 'predictions', 'or', 'decisions', 'without', 'being', 'explicitly', 'programmed', 'to', 'perform', 'the', 'task']
# DF
# {'amazon': 1, 'distributes': 1, 'downloads': 1, 'and': 4, 'streaming': 1, 'of': 4, 'video': 1, 'music': 1, 'audiobook': 1, 'through': 2, 'its': 3, 'prime': 1, 'audible': 1, 'subsidiaries': 1, 'also': 1, 'has': 1, 'a': 3, 'publishing': 1, 'arm': 1, 'film': 1, 'television': 1, 'studio': 1, 'studios': 1, 'cloud': 1, 'computing': 1, 'subsidiary': 1, 'web': 2, 'services': 2, 'microsoft': 1, 'corporation': 1, 'is': 2, 'an': 1, 'american': 1, 'multinational': 1, 'technology': 1, 'company': 2, 'with': 1, 'headquarters': 1, 'in': 3, 'redmond': 1, 'washington': 1, 'it': 2, 'develops': 1, 'manufactures': 1, 'licenses': 1, 'supports': 1, 'sells': 1, 'computer': 2, 'software': 1, 'consumer': 1, 'electronics': 1, 'personal': 1, 'computers': 1, 'related': 1, 'best': 1, 'known': 2, 'products': 1, 'are': 1, 'the': 3, 'windows': 1, 'line': 1, 'operating': 1, 'systems': 2, 'office': 1, 'suite': 1, 'internet': 1, 'explorer': 1, 'edge': 1, 'browsers': 1, 'google': 1, 'was': 1, 'founded': 1, '1998': 1, 'by': 1, 'larry': 1, 'page': 1, 'sergey': 1, 'brin': 1, 'while': 1, 'they': 1, 'were': 1, 'ph': 1, 'd': 1, 'students': 1, 'at': 1, 'stanford': 1, 'university': 1, 'california': 1, 'together': 1, 'own': 1, 'about': 1, '14': 1, 'percent': 1, 'shares': 1, 'control': 1, '56': 1, 'stockholder': 1, 'voting': 1, 'power': 1, 'supervoting': 1, 'stock': 1, 'incorporated': 1, 'as': 2, 'privately': 1, 'held': 1, 'on': 2, 'september': 1, '4': 1, 'machine': 1, 'learning': 1, 'ml': 1, 'scientific': 1, 'study': 1, 'algorithms': 1, 'statistical': 1, 'models': 1, 'that': 1, 'use': 1, 'order': 1, 'to': 1, 'perform': 1, 'specific': 1, 'task': 1, 'effectively': 1, 'without': 1, 'using': 1, 'explicit': 1, 'instructions': 1, 'relying': 1, 'patterns': 1, 'inference': 1, 'instead': 1, 'seen': 1, 'subset': 1, 'artificial': 1, 'intelligence': 1, 'build': 1, 'mathematical': 1, 'model': 1, 'based': 1, 'sample': 1, 'data': 1, 'training': 1, 'make': 1, 'predictions': 1, 'or': 1, 'decisions': 1, 'being': 1, 'explicitly': 1, 'programmed': 1}
# DF
# Frecuencia TF
# {'machine': 0.0273972602739726, 'learning': 0.0273972602739726, 'ml': 0.0136986301369863, 'is': 0.0273972602739726, 'the': 0.0273972602739726, 'scientific': 0.0136986301369863, 'study': 0.0136986301369863, 'of': 0.0273972602739726, 'algorithms': 0.0273972602739726, 'and': 0.0273972602739726, 'statistical': 0.0136986301369863, 'models': 0.0136986301369863, 'that': 0.0136986301369863, 'computer': 0.0136986301369863, 'systems': 0.0136986301369863, 'use': 0.0136986301369863, 'in': 0.0273972602739726, 'order': 0.0273972602739726, 'to': 0.0410958904109589, 'perform': 0.0273972602739726, 'a': 0.0410958904109589, 'specific': 0.0136986301369863, 'task': 0.0273972602739726, 'effectively': 0.0136986301369863, 'without': 0.0273972602739726, 'using': 0.0136986301369863, 'explicit': 0.0136986301369863, 'instructions': 0.0136986301369863, 'relying': 0.0136986301369863, 'on': 0.0273972602739726, 'patterns': 0.0136986301369863, 'inference': 0.0136986301369863, 'instead': 0.0136986301369863, 'it': 0.0136986301369863, 'seen': 0.0136986301369863, 'as': 0.0273972602739726, 'subset': 0.0136986301369863, 'artificial': 0.0136986301369863, 'intelligence': 0.0136986301369863, 'build': 0.0136986301369863, 'mathematical': 0.0136986301369863, 'model': 0.0136986301369863, 'based': 0.0136986301369863, 'sample': 0.0136986301369863, 'data': 0.0273972602739726, 'known': 0.0136986301369863, 'training': 0.0136986301369863, 'make': 0.0136986301369863, 'predictions': 0.0136986301369863, 'or': 0.0136986301369863, 'decisions': 0.0136986301369863, 'being': 0.0136986301369863, 'explicitly': 0.0136986301369863, 'programmed': 0.0136986301369863}
#
#
#
# TUPLAS
#
#
#
#
# {'amazon': 7, 'distributes': 1, 'downloads': 1, 'and': 12, 'streaming': 1, 'of': 6, 'video': 2, 'music': 2, 'audiobook': 1, 'through': 2, 'its': 3, 'prime': 1, 'audible': 1, 'subsidiaries': 1, 'also': 1, 'has': 1, 'a': 7, 'publishing': 2, 'arm': 1, 'film': 1, 'television': 1, 'studio': 1, 'studios': 1, 'cloud': 1, 'computing': 1, 'subsidiary': 1, 'web': 2, 'services': 2, 'microsoft': 3, 'corporation': 1, 'is': 3, 'an': 1, 'american': 1, 'multinational': 1, 'technology': 1, 'company': 2, 'with': 1, 'headquarters': 1, 'in': 5, 'redmond': 1, 'washington': 1, 'it': 2, 'develops': 1, 'manufactures': 1, 'licenses': 1, 'supports': 1, 'sells': 1, 'computer': 2, 'software': 2, 'consumer': 1, 'electronics': 1, 'personal': 1, 'computers': 1, 'related': 1, 'best': 1, 'known': 2, 'products': 1, 'are': 1, 'the': 6, 'windows': 1, 'line': 1, 'operating': 1, 'systems': 2, 'office': 1, 'suite': 1, 'internet': 1, 'explorer': 1, 'edge': 1, 'browsers': 1, 'google': 2, 'was': 1, 'founded': 1, '1998': 2, 'by': 1, 'larry': 1, 'page': 1, 'sergey': 1, 'brin': 1, 'while': 1, 'they': 3, 'were': 1, 'ph': 1, 'd': 1, 'students': 1, 'at': 1, 'stanford': 1, 'university': 1, 'california': 1, 'together': 1, 'own': 1, 'about': 1, '14': 1, 'percent': 2, 'shares': 1, 'control': 1, '56': 1, 'stockholder': 1, 'voting': 1, 'power': 1, 'supervoting': 1, 'stock': 1, 'incorporated': 1, 'as': 3, 'privately': 1, 'held': 1, 'on': 3, 'september': 1, '4': 1, 'machine': 2, 'learning': 2, 'ml': 1, 'scientific': 1, 'study': 1, 'algorithms': 2, 'statistical': 1, 'models': 1, 'that': 1, 'use': 1, 'order': 2, 'to': 3, 'perform': 2, 'specific': 1, 'task': 2, 'effectively': 1, 'without': 2, 'using': 1, 'explicit': 1, 'instructions': 1, 'relying': 1, 'patterns': 1, 'inference': 1, 'instead': 1, 'seen': 1, 'subset': 1, 'artificial': 1, 'intelligence': 1, 'build': 1, 'mathematical': 1, 'model': 1, 'based': 1, 'sample': 1, 'data': 2, 'training': 1, 'make': 1, 'predictions': 1, 'or': 1, 'decisions': 1, 'being': 1, 'explicitly': 1, 'programmed': 1}
#
#
# 10 most common words:
# Word	Count
#
# 10 least common words:
# Word	Count
#
#
# [('and', 12), ('amazon', 7), ('a', 7), ('of', 6), ('the', 6), ('in', 5), ('its', 3), ('microsoft', 3), ('is', 3), ('they', 3), ('as', 3), ('on', 3), ('to', 3), ('video', 2), ('music', 2), ('through', 2), ('publishing', 2), ('web', 2), ('services', 2), ('company', 2), ('it', 2), ('computer', 2), ('software', 2), ('known', 2), ('systems', 2), ('google', 2), ('1998', 2), ('percent', 2), ('machine', 2), ('learning', 2), ('algorithms', 2), ('order', 2), ('perform', 2), ('task', 2), ('without', 2), ('data', 2), ('distributes', 1), ('downloads', 1), ('streaming', 1), ('audiobook', 1), ('prime', 1), ('audible', 1), ('subsidiaries', 1), ('also', 1), ('has', 1), ('arm', 1), ('film', 1), ('television', 1), ('studio', 1), ('studios', 1), ('cloud', 1), ('computing', 1), ('subsidiary', 1), ('corporation', 1), ('an', 1), ('american', 1), ('multinational', 1), ('technology', 1), ('with', 1), ('headquarters', 1), ('redmond', 1), ('washington', 1), ('develops', 1), ('manufactures', 1), ('licenses', 1), ('supports', 1), ('sells', 1), ('consumer', 1), ('electronics', 1), ('personal', 1), ('computers', 1), ('related', 1), ('best', 1), ('products', 1), ('are', 1), ('windows', 1), ('line', 1), ('operating', 1), ('office', 1), ('suite', 1), ('internet', 1), ('explorer', 1), ('edge', 1), ('browsers', 1), ('was', 1), ('founded', 1), ('by', 1), ('larry', 1), ('page', 1), ('sergey', 1), ('brin', 1), ('while', 1), ('were', 1), ('ph', 1), ('d', 1), ('students', 1), ('at', 1), ('stanford', 1), ('university', 1), ('california', 1), ('together', 1), ('own', 1), ('about', 1), ('14', 1), ('shares', 1), ('control', 1), ('56', 1), ('stockholder', 1), ('voting', 1), ('power', 1), ('supervoting', 1), ('stock', 1), ('incorporated', 1), ('privately', 1), ('held', 1), ('september', 1), ('4', 1), ('ml', 1), ('scientific', 1), ('study', 1), ('statistical', 1), ('models', 1), ('that', 1), ('use', 1), ('specific', 1), ('effectively', 1), ('using', 1), ('explicit', 1), ('instructions', 1), ('relying', 1), ('patterns', 1), ('inference', 1), ('instead', 1), ('seen', 1), ('subset', 1), ('artificial', 1), ('intelligence', 1), ('build', 1), ('mathematical', 1), ('model', 1), ('based', 1), ('sample', 1), ('training', 1), ('make', 1), ('predictions', 1), ('or', 1), ('decisions', 1), ('being', 1), ('explicitly', 1), ('programmed', 1)]
#
# .............................................................................................
#
#
# Libro #  5
# In computer science, artificial intelligence (AI), sometimes called machine intelligence, is intelligence demonstrated by machines, in contrast to the natural intelligence displayed by humans. Colloquially, the term "artificial intelligence" is often used to describe machines (or computers) that mimic "cognitive" functions that humans associate with the human mind, such as "learning" and "problem solving".
#
#
# ['in', 'computer', 'science', 'artificial', 'intelligence', 'ai', 'sometimes', 'called', 'machine', 'intelligence', 'is', 'intelligence', 'demonstrated', 'by', 'machines', 'in', 'contrast', 'to', 'the', 'natural', 'intelligence', 'displayed', 'by', 'humans', 'colloquially', 'the', 'term', 'artificial', 'intelligence', 'is', 'often', 'used', 'to', 'describe', 'machines', 'or', 'computers', 'that', 'mimic', 'cognitive', 'functions', 'that', 'humans', 'associate', 'with', 'the', 'human', 'mind', 'such', 'as', 'learning', 'and', 'problem', 'solving']
# DF
# {'amazon': 1, 'distributes': 1, 'downloads': 1, 'and': 5, 'streaming': 1, 'of': 4, 'video': 1, 'music': 1, 'audiobook': 1, 'through': 2, 'its': 3, 'prime': 1, 'audible': 1, 'subsidiaries': 1, 'also': 1, 'has': 1, 'a': 3, 'publishing': 1, 'arm': 1, 'film': 1, 'television': 1, 'studio': 1, 'studios': 1, 'cloud': 1, 'computing': 1, 'subsidiary': 1, 'web': 2, 'services': 2, 'microsoft': 1, 'corporation': 1, 'is': 3, 'an': 1, 'american': 1, 'multinational': 1, 'technology': 1, 'company': 2, 'with': 2, 'headquarters': 1, 'in': 4, 'redmond': 1, 'washington': 1, 'it': 2, 'develops': 1, 'manufactures': 1, 'licenses': 1, 'supports': 1, 'sells': 1, 'computer': 3, 'software': 1, 'consumer': 1, 'electronics': 1, 'personal': 1, 'computers': 2, 'related': 1, 'best': 1, 'known': 2, 'products': 1, 'are': 1, 'the': 4, 'windows': 1, 'line': 1, 'operating': 1, 'systems':
 'shares': 1, 'control': 1, '56': 1, 'stockholder': 1, 'voting': 1, 'power': 1, 'supervoting': 1, 'stock': 1, 'incorporated': 1, 'as': 4, 'privately': 1, 'held': 1, 'on': 3, 'september': 1, '4': 1, 'machine': 3, 'learning': 3, 'ml': 1, 'scientific': 1, 'study': 1, 'algorithms': 2, 'statistical': 1, 'models': 1, 'that': 3, 'use': 1, 'order': 2, 'to': 5, 'perform': 2, 'specific': 1, 'task': 2, 'effectively': 1, 'without': 2, 'using': 1, 'explicit': 1, 'instructions': 1, 'relying': 1, 'patterns': 1, 'inference': 1, 'instead': 1, 'seen': 1, 'subset': 1, 'artificial': 3, 'intelligence': 6, 'build': 1, 'mathematical': 1, 'model': 1, 'based': 1, 'sample': 1, 'data': 2, 'training': 1, 'make': 1, 'predictions': 1, 'or': 2, 'decisions': 1, 'being': 1, 'explicitly': 1, 'programmed': 1, 'science': 1, 'ai': 1, 'sometimes': 1, 'called': 1, 'demonstrated': 1, 'machines': 2, 'contrast': 1, 'natural': 1, 'displayed': 1, 'humans': 2, 'colloquially': 1, 'term': 1, 'often': 1, 'used': 1, 'describe': 1, 'mimic': 1, 'cognitive': 1, 'functions': 1, 'associate': 1, 'human': 1, 'mind': 1, 'such': 1, 'problem': 1, 'solving': 1}
#
#
# 10 most common words:
# Word	Count
#
# 10 least common words:
# Word	Count
#
#
# [('and', 13), ('the', 9), ('amazon', 7), ('a', 7), ('in', 7), ('of', 6), ('intelligence', 6), ('is', 5), ('to', 5), ('as', 4), ('its', 3), ('microsoft', 3), ('computer', 3), ('by', 3), ('they', 3), ('on', 3), ('machine', 3), ('learning', 3), ('that', 3), ('artificial', 3), ('video', 2), ('music', 2), ('through', 2), ('publishing', 2), ('web', 2), ('services', 2), ('company', 2), ('with', 2), ('it', 2), ('software', 2), ('computers', 2), ('known', 2), ('systems', 2), ('google', 2), ('1998', 2), ('percent', 2), ('algorithms', 2), ('order', 2), ('perform', 2), ('task', 2), ('without', 2), ('data', 2), ('or', 2), ('machines', 2), ('humans', 2), ('distributes', 1), ('downloads', 1), ('streaming', 1), ('audiobook', 1), ('prime', 1), ('audible', 1), ('subsidiaries', 1), ('also', 1), ('has', 1), ('arm', 1), ('film', 1), ('television', 1), ('studio', 1), ('studios', 1), ('cloud', 1), ('computing', 1), ('subsidiary', 1), ('corporation', 1), ('an', 1), ('american', 1), ('multinational', 1), ('technology', 1), ('headquarters', 1), ('redmond', 1), ('washington', 1), ('develops', 1), ('manufactures', 1), ('licenses', 1), ('supports', 1), ('sells', 1), ('consumer', 1), ('electronics', 1), ('personal', 1), ('related', 1), ('best', 1), ('products', 1), ('are', 1), ('windows', 1), ('line', 1), ('operating', 1), ('office', 1), ('suite', 1), ('internet', 1), ('explorer', 1), ('edge', 1), ('browsers', 1), ('was', 1), ('founded', 1), ('larry', 1), ('page', 1), ('sergey', 1), ('brin', 1), ('while', 1), ('were', 1), ('ph', 1), ('d', 1), ('students', 1), ('at', 1), ('stanford', 1), ('university', 1), ('california', 1), ('together', 1), ('own', 1), ('about', 1), ('14', 1), ('shares', 1), ('control', 1), ('56', 1), ('stockholder', 1), ('voting', 1), ('power', 1), ('supervoting', 1), ('stock', 1), ('incorporated', 1), ('privately', 1), ('held', 1), ('september', 1), ('4', 1), ('ml', 1), ('scientific', 1), ('study', 1), ('statistical', 1), ('models', 1), ('use', 1), ('specific', 1), ('effectively', 1), ('using', 1), ('explicit', 1), ('instructions', 1), ('relying', 1), ('patterns', 1), ('inference', 1), ('instead', 1), ('seen', 1), ('subset', 1), ('build', 1), ('mathematical', 1), ('model', 1), ('based', 1), ('sample', 1), ('training', 1), ('make', 1), ('predictions', 1), ('decisions', 1), ('being', 1), ('explicitly', 1), ('programmed', 1), ('science', 1), ('ai', 1), ('sometimes', 1), ('called', 1), ('demonstrated', 1), ('contrast', 1), ('natural', 1), ('displayed', 1), ('colloquially', 1), ('term', 1), ('often', 1), ('used', 1), ('describe', 1), ('mimic', 1), ('cognitive', 1), ('functions', 1), ('associate', 1), ('human', 1), ('mind', 1), ('such', 1), ('problem', 1), ('solving', 1)]
#
# .............................................................................................
#
#
# Libro #  6
# In information retrieval, tf–idf or TFIDF, short for term frequency–inverse document frequency, is a numerical statistic that is intended to reflect how important a word is to a document in a collection or corpus.
#
#
# ['in', 'information', 'retrieval', 'tf', 'idf', 'or', 'tfidf', 'short', 'for', 'term', 'frequency', 'inverse', 'document', 'frequency', 'is', 'a', 'numerical', 'statistic', 'that', 'is', 'intended', 'to', 'reflect', 'how', 'important', 'a', 'word', 'is', 'to', 'a', 'document', 'in', 'a', 'collection', 'or', 'corpus']
# DF
# {'amazon': 1, 'distributes': 1, 'downloads': 1, 'and': 5, 'streaming': 1, 'of': 4, 'video': 1, 'music': 1, 'audiobook': 1, 'through': 2, 'its': 3, 'prime': 1, 'audible': 1, 'subsidiaries': 1, 'also': 1, 'has': 1, 'a': 4, 'publishing': 1, 'arm': 1, 'film': 1, 'television': 1, 'studio': 1, 'studios': 1, 'cloud': 1, 'computing': 1, 'subsidiary': 1, 'web': 2, 'services': 2, 'microsoft': 1, 'corporation': 1, 'is': 4, 'an': 1, 'american': 1, 'multinational': 1, 'technology': 1, 'company': 2, 'with': 2, 'headquarters': 1, 'in': 5, 'redmond': 1, 'washington': 1, 'it': 2, 'develops': 1, 'manufactures': 1, 'licenses': 1, 'supports': 1, 'sells': 1, 'computer': 3, 'software': 1, 'consumer': 1, 'electronics': 1, 'personal': 1, 'computers': 2, 'related': 1, 'best': 1, 'known': 2, 'products': 1, 'are': 1, 'the': 4, 'windows': 1, 'line': 1, 'operating': 1, 'systems': 2, 'office': 1, 'suite': 1, 'internet': 1, 'explorer': 1, 'edge': 1, 'browsers': 1, 'google': 1, 'was': 1, 'founded': 1, '1998': 1, 'by': 2, 'larry': 1, 'page': 1, 'sergey': 1, 'brin': 1, 'while': 1, 'they': 1, 'were': 1, 'ph': 1, 'd': 1, 'students': 1, 'at': 1, 'stanford': 1, 'university': 1, 'california': 1, 'together': 1, 'own': 1, 'about': 1, '14': 1, 'percent': 1, 'shares': 1, 'control': 1, '56': 1, 'stockholder': 1, 'voting': 1, 'power': 1, 'supervoting': 1, 'stock': 1, 'incorporated': 1, 'as': 3, 'privately': 1, 'held': 1, 'on': 2, 'september': 1, '4': 1, 'machine': 2, 'learning': 2, 'ml': 1, 'scientific': 1, 'study': 1, 'algorithms': 1, 'statistical': 1, 'models': 1, 'that': 3, 'use': 1, 'order': 1, 'to': 3, 'perform': 1, 'specific': 1, 'task': 1, 'effectively': 1, 'without': 1, 'using': 1, 'explicit': 1, 'instructions': 1, 'relying': 1, 'patterns': 1, 'inference': 1, 'instead': 1, 'seen': 1, 'subset': 1, 'artificial': 2, 'intelligence': 2, 'build': 1, 'mathematical': 1, 'model': 1, 'based': 1, 'sample': 1, 'data': 1, 'training': 1, 'make': 1, 'predictions': 1, 'or': 3, 'decisions': 1, 'being': 1, 'explicitly': 1, 'programmed': 1, 'science': 1, 'ai': 1, 'sometimes': 1, 'called': 1, 'demonstrated': 1, 'machines': 1, 'contrast': 1, 'natural': 1, 'displayed': 1, 'humans': 1, 'colloquially': 1, 'term': 2, 'often': 1, 'used': 1, 'describe': 1, 'mimic': 1, 'cognitive': 1, 'functions': 1, 'associate': 1, 'human': 1, 'mind': 1, 'such': 1, 'problem': 1, 'solving': 1, 'information': 1, 'retrieval': 1, 'tf': 1, 'idf': 1, 'tfidf': 1, 'short': 1, 'for': 1, 'frequency': 1, 'inverse': 1, 'document': 1, 'numerical': 1, 'statistic': 1, 'intended': 1, 'reflect': 1, 'how': 1, 'important': 1, 'word': 1, 'collection': 1, 'corpus': 1}
# DF
# Frecuencia TF
# {'in': 0.05555555555555555, 'information': 0.027777777777777776, 'retrieval': 0.027777777777777776, 'tf': 0.027777777777777776, 'idf': 0.027777777777777776, 'or': 0.05555555555555555, 'tfidf': 0.027777777777777776, 'short': 0.027777777777777776, 'for': 0.027777777777777776, 'term': 0.027777777777777776, 'frequency': 0.05555555555555555, 'inverse': 0.027777777777777776, 'document': 0.05555555555555555, 'is': 0.08333333333333333, 'a': 0.1111111111111111, 'numerical': 0.027777777777777776, 'statistic': 0.027777777777777776, 'that': 0.027777777777777776, 'intended': 0.027777777777777776, 'to': 0.05555555555555555, 'reflect': 0.027777777777777776, 'how': 0.027777777777777776, 'important': 0.027777777777777776, 'word': 0.027777777777777776, 'collection': 0.027777777777777776, 'corpus': 0.027777777777777776}
#
#
#
# TUPLAS
#
#
#
#
# {'amazon': 7, 'distributes': 1, 'downloads': 1, 'and': 13, 'streaming': 1, 'of': 6, 'video': 2, 'music': 2, 'audiobook': 1, 'through': 2, 'its': 3, 'prime': 1, 'audible': 1, 'subsidiaries': 1, 'also': 1, 'has': 1, 'a': 11, 'publishing': 2, 'arm': 1, 'film': 1, 'television': 1, 'studio': 1, 'studios': 1, 'cloud': 1, 'computing': 1, 'subsidiary': 1, 'web': 2, 'services': 2, 'microsoft': 3, 'corporation': 1, 'is': 8, 'an': 1, 'american': 1, 'multinational': 1, 'technology': 1, 'company': 2, 'with': 2, 'headquarters': 1, 'in': 9, 'redmond': 1, 'washington': 1, 'it': 2, 'develops': 1, 'manufactures': 1, 'licenses': 1, 'supports': 1, 'sells': 1, 'computer': 3, 'software': 2, 'consumer': 1, 'electronics': 1, 'personal': 1, 'computers': 2, 'related': 1, 'best': 1, 'known': 2, 'products': 1, 'are': 1, 'the': 9, 'windows': 1, 'line': 1, 'operating': 1, 'systems': 2, 'office': 1, 'suite': 1, 'internet': 1, 'explorer': 1, 'edge': 1, 'browsers': 1, 'google': 2, 'was': 1, 'founded': 1, '1998': 2, 'by': 3, 'larry': 1, 'page': 1, 'sergey': 1, 'brin': 1, 'while': 1, 'they': 3, 'were': 1, 'ph': 1, 'd': 1, 'students': 1, 'at': 1, 'stanford': 1, 'university': 1, 'california': 1, 'together': 1, 'own': 1, 'about': 1, '14': 1, 'percent': 2, 'shares': 1, 'control': 1, '56': 1, 'stockholder': 1, 'voting': 1, 'power': 1, 'supervoting': 1, 'stock': 1, 'incorporated': 1, 'as': 4, 'privately': 1, 'held': 1, 'on': 3, 'september': 1, '4': 1, 'machine': 3, 'learning': 3, 'ml': 1, 'scientific': 1, 'study': 1, 'algorithms': 2, 'statistical': 1, 'models': 1, 'that': 4, 'use': 1, 'order': 2, 'to': 7, 'perform': 2, 'specific': 1, 'task': 2, 'effectively': 1, 'without': 2, 'using': 1, 'explicit': 1, 'instructions': 1, 'relying': 1, 'patterns': 1, 'inference': 1, 'instead': 1, 'seen': 1, 'subset': 1, 'artificial': 3, 'intelligence': 6, 'build': 1, 'mathematical': 1, 'model': 1, 'based': 1, 'sample': 1, 'data': 2, 'training': 1, 'make': 1, 'predictions': 1, 'or': 4, 'decisions': 1, 'being': 1, 'explicitly': 1, 'programmed': 1, 'science': 1, 'ai': 1, 'sometimes': 1, 'called': 1, 'demonstrated': 1, 'machines': 2, 'contrast': 1, 'natural': 1, 'displayed': 1, 'humans': 2, 'colloquially': 1, 'term': 2, 'often': 1, 'used': 1, 'describe': 1, 'mimic': 1, 'cognitive': 1, 'functions': 1, 'associate': 1, 'human': 1, 'mind': 1, 'such': 1, 'problem': 1, 'solving': 1, 'information': 1, 'retrieval': 1, 'tf': 1, 'idf': 1, 'tfidf': 1, 'short': 1, 'for': 1, 'frequency': 2, 'inverse': 1, 'document': 2, 'numerical': 1, 'statistic': 1, 'intended': 1, 'reflect': 1, 'how': 1, 'important': 1, 'word': 1, 'collection': 1, 'corpus': 1}
#
# .............................................................................................
#
#
# Libro #  7
# Information retrieval (IR) is the activity of obtaining information system resources that are relevant to an information need from a collection of those resources. Searches can be based on full-text or other content-based indexing. Information retrieval is the science of searching for information in a document, searching for documents themselves, and also searching for the metadata that describes data, and for databases of texts, images or sounds.
#
#
# ['information', 'retrieval', 'ir', 'is', 'the', 'activity', 'of', 'obtaining', 'information', 'system', 'resources', 'that', 'are', 'relevant', 'to', 'an', 'information', 'need', 'from', 'a', 'collection', 'of', 'those', 'resources', 'searches', 'can', 'be', 'based', 'on', 'full', 'text', 'or', 'other', 'content', 'based', 'indexing', 'information', 'retrieval', 'is', 'the', 'science', 'of', 'searching', 'for', 'information', 'in', 'a', 'document', 'searching', 'for', 'documents', 'themselves', 'and', 'also', 'searching', 'for', 'the', 'metadata', 'that', 'describes', 'data', 'and', 'for', 'databases', 'of', 'texts', 'images', 'or', 'sounds']
# DF
# ...
# DF
# Frecuencia TF
# {'a': 0.0364963503649635, 'mobile': 0.021897810218978103, 'device': 0.021897810218978103, 'or': 0.029197080291970802, 'handheld': 0.014598540145985401, 'computer': 0.014598540145985401, 'is': 0.014598540145985401, 'computing': 0.0072992700729927005, 'small': 0.0072992700729927005, 'enough': 0.0072992700729927005, 'to': 0.029197080291970802, 'hold': 0.0072992700729927005, 'and': 0.043795620437956206, 'operate': 0.0072992700729927005, 'in': 0.0072992700729927005, 'the': 0.021897810218978103, 'hand': 0.0072992700729927005, 'typically': 0.014598540145985401, 'any': 0.0072992700729927005, 'will': 0.0072992700729927005, 'have': 0.0072992700729927005, 'an': 0.0072992700729927005, 'lcd': 0.0072992700729927005, 'fhd': 0.0072992700729927005, 'oled': 0.0072992700729927005, 'flatscreen': 0.0072992700729927005, 'interface': 0.0072992700729927005, 'providing': 0.0072992700729927005, 'touchscreen': 0.0072992700729927005, 'android': 0.0072992700729927005, 'version': 0.0072992700729927005, '9': 0.0072992700729927005, '0interface': 0.0072992700729927005, 'with': 0.021897810218978103, 'digital': 0.014598540145985401, 'buttons': 0.014598540145985401, 'keyboard': 0.014598540145985401, 'physical': 0.014598540145985401, 'along': 0.0072992700729927005, 'many': 0.0072992700729927005, 'such': 0.014598540145985401, 'devices': 0.021897810218978103, 'can': 0.0072992700729927005, 'connect': 0.0072992700729927005, 'internet': 0.0072992700729927005, 'interconnect': 0.0072992700729927005, 'other': 0.0072992700729927005, 'as': 0.0072992700729927005, 'car': 0.0072992700729927005, 'entertainment': 0.0072992700729927005, 'systems': 0.014598540145985401, 'headsets': 0.0072992700729927005, 'via': 0.0072992700729927005, 'wi': 0.0072992700729927005, 'fi': 0.0072992700729927005, 'bluetooth': 0.0072992700729927005, 'cellular': 0.0072992700729927005, 'networks': 0.0072992700
': 3, 'learning': 3, 'ml': 1, 'scientific': 1, 'study': 1, 'algorithms': 2, 'statistical': 1, 'models': 1, 'that': 10, 'use': 1, 'order': 3, 'to': 21, 'perform': 2, 'specific': 1, 'task': 2, 'effectively': 1, 'without': 2, 'using': 1, 'explicit': 1, 'instructions': 1, 'relying': 1, 'patterns': 1, 'inference': 1, 'instead': 1, 'seen': 1, 'subset': 1, 'artificial': 3, 'intelligence': 6, 'build': 1, 'mathematical': 1, 'model': 1, 'based': 3, 'sample': 1, 'data': 3, 'training': 1, 'make': 1, 'predictions': 1, 'or': 12, 'decisions': 1, 'being': 1, 'explicitly': 1, 'programmed': 1, 'science': 2, 'ai': 1, 'sometimes': 1, 'called': 1, 'demonstrated': 1, 'machines': 2, 'contrast': 1, 'natural': 1, 'displayed': 2, 'humans': 2, 'colloquially': 1, 'term': 2, 'often': 3, 'used': 1, 'describe': 1, 'mimic': 1, 'cognitive': 1, 'functions': 1, 'associate': 1, 'human': 1, 'mind': 1, 'such': 4, 'problem': 1, 'solving': 1, 'information': 9, 'retrieval': 3, 'tf': 1, 'idf': 1, 'tfidf': 1, 'short': 1, 'for': 9, 'frequency': 2, 'inverse': 1, 'document': 4, 'numerical': 1, 'statistic': 1, 'intended': 1, 'reflect': 1, 'how': 1, 'important': 1, 'word': 1, 'collection': 2, 'corpus': 1, 'ir': 1, 'activity': 1, 'obtaining': 1, 'system': 4, 'resources': 4, 'relevant': 1, 'need': 1, 'from': 3, 'those': 1, 'searches': 1, 'can': 3, 'be': 4, 'full': 1, 'text': 1, 'other': 4, 'content': 1, 'indexing': 1, 'searching': 3, 'documents': 3, 'themselves': 1, 'metadata': 1, 'describes': 1, 'databases': 1, 'texts': 1, 'images': 1, 'sounds': 1, 'search': 8, 'engine': 3, 'designed': 1, 'carry': 1, 'out': 1, 'which': 3, 'means': 1, 'world': 4, 'wide': 4, 'systematic': 1, 'way': 1, 'particular': 1, 'specified': 1, 'textual': 1, 'query': 1, 'results': 3, 'generally': 1, 'presented': 1, 'referred': 3, 'pages': 4, 'serps': 1, 'www': 2, 'commonly': 2, 'where': 1, 'identified': 2, 'uniform': 2, 'resource': 3, 'locators': 1, 'urls': 1, 'https': 1, 'example': 1, 'com': 1, 'may': 3, 'interlinked': 1, 'hypertext': 2, 'accessible': 1, 'over': 1, 'browser': 4, 'application': 1, 'accessing': 1, 'each': 1, 'individual': 1, 'image': 1, 'distinct': 1, 'locator': 1, 'url': 1, 'enabling': 1, 'retrieve': 2, 'these': 1, 'server': 1, 'display': 2, 'them': 1, 'user': 1, 's': 1, 'device': 5, 'written': 1, 'webpage': 1, 'suitable': 1, 'act': 1, 'graphically': 1, 'needed': 1, 'this': 1, 'type': 1, 'when': 1, 'accessed': 1, 'monitor': 1, 'mobile': 4, 'typical': 1, 'contain': 1, 'hyperlinks': 1, '1': 1, 'links': 1, 'browsing': 1, 'handheld': 2, 'small': 1, 'enough': 1, 'hold': 1 ...
#
#
# 10 most common words:
# Word	Count
#
# 10 least common words:
# Word	Count
#
#
# [('a', 38), ('and', 25), ('web', 23), ('the', 23), ('is', 21), ('to', 21), ('in', 15), ('as', 13), ('of', 12), ('or', 12), ('that', 10), ('information', 9), ('for', 9), ('by', 8), ('on', 8), ('search', 8), ('amazon', 7), ('are', 7), ('internet', 6), ('intelligence', 6), ('with', 5), ('computer', 5), ('software', 5), ('page', 5), ('device', 5), ('video', 4), ('an', 4), ('systems', 4), ('such', 4), ('document', 4), ('system', 4), ('resources', 4), ('be', 4), ('other', 4), ('world', 4), ('wide', 4), ('pages', 4), ('browser', 4), ('mobile', 4), ('its', 3), ('also', 3), ('microsoft', 3), ('it', 3), ('known', 3), ('they', 3), ('machine', 3), ('learning', 3), ('order', 3), ('artificial', 3), ('based', 3), ('data', 3), ('often', 3), ('retrieval', 3), ('from', 3), ('can', 3), ('searching', 3), ('documents', 3), ('engine', 3), ('which', 3), ('results', 3), ('referred', 3), ('resource', 3), ('may', 3), ('devices', 3), ('music', 2), ('through', 2), ('publishing', 2), ('computing', 2), ('services', 2), ('company', 2), ('computers', 2), ('line', 2), ('operating', 2), ('browsers', 2), ('google', 2), ('1998', 2), ('percent', 2), ('power', 2), ('algorithms', 2), ('perform', 2), ('task', 2), ('without', 2), ('science', 2), ('machines', 2), ('displayed', 2), ('humans', 2), ('term', 2), ('frequency', 2), ('collection', 2), ('www', 2), ('commonly', 2), ('identified', 2), ('uniform', 2), ('hypertext', 2), ('retrieve', 2), ('display', 2), ('handheld', 2), ('typically', 2), ('digital', 2), ('buttons', 2), ('keyboard', 2), ('physical', 2), ('capabilities', 2), ('run', 2), ('distributes', 1), ('downloads', 1), ('streaming', 1), ('audiobook', 1), ('prime', 1), ('audible', 1), ('subsidiaries', 1), ('has', 1), ('arm', 1), ('film', 1), ('television', 1), ('studio', 1), ('studios', 1), ('cloud', 1), ('subsidiary', 1), ('corporation', 1), ('american', 1), ('multinational', 1), ('technology', 1), ('headquarters', 1), ('redmond', 1), ('washington', 1), ('develops', 1), ('manufactures', 1), ('licenses', 1), ('supports', 1), ('sells', 1), ('consumer', 1), ('electronics', 1), ('personal', 1), ('related', 1), ('best', 1), ('products', 1), ('windows', 1), ('office', 1), ('suite', 1), ('explorer', 1), ('edge', 1), ('was', 1), ('founded', 1), ('larry', 1), ('sergey', 1), ('brin', 1), ('while', 1), ('were', 1), ('ph', 1), ('d', 1), ('students', 1), ('at', 1), ('stanford', 1), ('university', 1), ('california', 1), ('together', 1), ('own', 1), ('about', 1), ('14', 1), ('shares', 1), ('control', 1), ('56', 1), ('stockholder', 1), ('voting', 1), ('supervoting', 1), ('stock', 1), ('incorporated', 1), ('privately', 1), ('held', 1), ('september', 1), ('4', 1), ('ml', 1), ('scientific', 1), ('study', 1), ('statistical', 1), ('models', 1), ('use', 1), ('specific', 1), ('effectively', 1), ('using', 1), ('explicit', 1), ('instructions', 1), ('relying', 1), ('patterns', 1), ('inference', 1), ('instead', 1), ('seen', 1), ('subset', 1), ('build', 1), ('mathematical', 1), ('model', 1), ('sample', 1), ('training', 1), ('make', 1), ('predictions', 1), ('decisions', 1), ('being', 1), ('explicitly', 1), ('programmed', 1), ('ai', 1), ('sometimes', 1), ('called', 1), ('demonstrated', 1), ('contrast', 1), ('natural', 1), ('colloquially', 1), ('used', 1), ('describe', 1), ('mimic', 1), ('cognitive', 1), ('functions', 1), ('associate', 1), ('human', 1), ('mind', 1), ('problem', 1), ('solving', 1), ('tf', 1), ('idf', 1), ('tfidf', 1), ('short', 1), ('inverse', 1), ('numerical', 1), ('statistic', 1), ('intended', 1), ('reflect', 1), ('how', 1), ('important', 1), ('word', 1), ('corpus', 1), ('ir', 1), ('activity', 1), ('obtaining', 1), ('relevant', 1), ('need', 1), ('those', 1), ('searches', 1), ('full', 1), ('text', 1), ('content', 1), ('indexing', 1), ('themselves', 1), ('metadata', 1), ('describes', 1), ('databases', 1), ('texts', 1), ('images', 1), ('sounds', 1), ('designed', 1), ('carry', 1), ('out', 1), ('means', 1), ('systematic', 1), ('way', 1), ('particular', 1), ('specified', 1), ('te ...
#
# idf
# {'amazon': 0.0, 'distributes': 0.0, 'downloads': 0.0, 'and': 0.0, 'streaming': 0.0, 'of': 0.0, 'video': 0.0, 'music': 0.0, 'audiobook': 0.0, 'through': 0.0, 'its': 0.0, 'prime': 0.0, 'audible': 0.0, 'subsidiaries': 0.0, 'also': 0.0, 'has': 0.0, 'a': 0.0, 'publishing': 0.0, 'arm': 0.0, 'film': 0.0, 'television': 0.0, 'studio': 0.0, 'studios': 0.0, 'cloud': 0.0, 'computing': 0.0, 'subsidiary': 0.0, 'web': 0.0, 'services': 0.0, 'microsoft': 0.0, 'corporation': 0.0, 'is': 0.0, 'an': 0.0, 'american': 0.0, 'multinational': 0.0, 'technology': 0.0, 'company': 0.0, 'with': 0.0, 'headquarters': 0.0, 'in': 0.0, 'redmond': 0.0, 'washington': 0.0, 'it': 0.0, 'develops': 0.0, 'manufactures': 0.0, 'licenses': 0.0, 'supports': 0.0, 'sells': 0.0, 'computer': 0.0, 'software': 0.0, 'consumer': 0.0, 'electronics': 0.0, 'personal': 0.0, 'computers': 0.0, 'related': 0.0, 'best': 0.0, 'known': 0.0, 'products': 0.0, 'are': 0.0, 'the': 0.0, 'windows': 0.0, 'line': 0.0, 'operating': 0.0, 'systems': 0.0, 'office': 0.0, 'suite': 0.0, 'internet': 0.0, 'explorer': 0.0, 'edge': 0.0, 'browsers': 0.0, 'google': 0.0, 'was': 0.0, 'founded': 0.0, '1998': 0.0, 'by': 0.0, 'larry': 0.0, 'page': 0.0, 'sergey': 0.0, 'brin': 0.0, 'while': 0.0, 'they': 0.0, 'were': 0.0, 'ph': 0.0, 'd': 0.0, 'students': 0.0, 'at': 0.0, 'stanford': 0.0, 'university': 0.0, 'california': 0.0, 'together': 0.0, 'own': 0.0, 'about': 0.0, '14': 0.0, 'percent': 0.0, 'shares': 0.0, 'control': 0.0, '56': 0.0, 'stockholder': 0.0, 'voting': 0.0, 'power': 0.0, 'supervoting': 0.0, 'stock': 0.0, 'incorporated': 0.0, 'as': 0.0, 'privately': 0.0, 'held': 0.0, 'on': 0.0, 'september': 0.0, '4': 0.0, 'machine': 0.0, 'learning': 0.0, 'ml': 0.0, 'scientific': 0.0, 'study': 0.0, 'algorithms': 0.0, 'statistical': 0.0, 'models': 0.0, 'that': 0.0, 'use': 0.0, 'order': 0.0, 'to': 0.0, 'perform': 0.0, 'specific': 0.0, 'task': 0.0, 'effectively': 0.0, 'without': 0.0, 'using': 0.0, 'explicit': 0.0, 'instructions': 0.0, 'relying': 0.0, 'patterns': 0.0, 'inference': 0.0, 'instead': 0.0, 'seen': 0.0, 'subset': 0.0, 'artificial': 0.0, 'intelligence': 0.0, 'build': 0.0, 'mathematical': 0.0, 'model': 0.0, 'based': 0.0, 'sample': 0.0, 'data': 0.0, 'training': 0.0, 'make': 0.0, 'predictions': 0.0, 'or': 0.0, 'decisions': 0.0, 'being': 0.0, 'explicitly': 0.0, 'programmed': 0.0, 'science': 0.0, 'ai': 0.0, 'sometimes': 0.0, 'called': 0.0, 'demonstrated': 0.0, 'machines': 0.0, 'contrast': 0.0, 'natural': 0.0, 'displayed': 0.0, 'humans': 0.0, 'colloquially': 0.0, 'term': 0.0, 'often': 0.0, 'used': 0.0, 'describe': 0.0, 'mimic': 0.0, 'cognitive': 0.0, 'functions': 0.0, 'associate': 0.0, 'human': 0.0, 'mind': 0.0, 'such': 0.0, 'problem': 0.0, 'solving': 0.0, 'information': 0.0, 'retrieval': 0.0, 'tf': 0.0, 'idf': 0.0, 'tfidf': 0.0, 'short': 0.0, 'for': 0.0, 'frequency': 0.0, 'inverse': 0.0, 'document': 0.0, 'numerical': 0.0, 'statistic': 0.0, 'intended': 0.0, 'reflect': 0.0, 'how': 0.0, 'important': 0.0, 'word': 0.0, 'collection': 0.0, 'corpus': 0.0, 'ir': 0.0, 'activity': 0.0, 'obtaining': 0.0, 'system': 0.0, 'resources': 0.0, 'relevant': 0.0, 'need': 0.0, 'from': 0.0, 'those': 0.0, 'searches': 0.0, 'can': 0.0, 'be': 0.0, 'full': 0.0, 'text': 0.0, 'other': 0.0, 'content': 0.0, 'indexing': 0.0, 'searching': 0.0, 'documents': 0.0, 'themselves': 0.0, 'metadata': 0.0, 'describes': 0.0, 'databases': 0.0, 'texts': 0.0, 'images': 0.0, 'sounds': 0.0, 'search': 0.0, 'engine': 0.0, 'designed': 0.0, 'carry': 0.0, 'out': 0.0, 'which': 0.0, 'means': 0.0, 'world': 0.0, 'wide': 0.0, 'systematic': 0.0, 'way': 0.0, 'particular': 0.0, 'specified': 0.0, 'textual': 0.0, 'query': 0.0, 'results': 0.0, 'generally': 0.0, 'presented': 0.0, 'referred': 0.0, 'pages': 0.0, 'serps': 0.0, 'www': 0.0, 'commonly': 0.0, 'where': 0.0, 'identified': 0.0, 'uniform': 0.0, 'resource': 0.0, 'locators': 0.0, 'urls': 0.0, 'https': 0.0, 'example': 0.0, 'com': 0.0, 'may': 0.0, 'interlinked': 0.0, 'hypertext': 0.0, 'accessible': 0.0, 'over': 0.0, 'browser': 0.0, 'applicati ...
# idf
